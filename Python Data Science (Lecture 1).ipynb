# %% [markdown]
# <a href="https://colab.research.google.com/github/saydulakbarmurad/pytorch/blob/main/Python%20Data%20Science%20(Lecture%201).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = input()
y = input()
# Out:
# 3
# 4

# %%
int(x)+int(y)
# Out:
# 7
